# %%
import torch
from torch import nn

torch.__version__
# Out:
# '1.12.1+cu102'

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
import requests
import zipfile
from pathlib import Path
import os

data_path = Path("data/")
basename = "pizza_steak_sushi"
ext = '.zip'
image_path = data_path / basename

image_path.mkdir(parents=True,
                 exist_ok=True)

with open(data_path / (basename + ext), "wb") as f:
    request = requests.get("https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/" + basename + ext)
    f.write(request.content)

with zipfile.ZipFile(data_path / (basename + ext), "r") as zip_ref:
    zip_ref.extractall(image_path)

os.remove(data_path / (basename + ext))

# %%
import os


def walk_through_dir(dir_path):
    for dirpath, dirnames, filenames in os.walk(dir_path):
        print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}.")


walk_through_dir(image_path)
# Out:
# There are 2 directories and 0 images in data/pizza_steak_sushi.
# There are 3 directories and 0 images in data/pizza_steak_sushi/train.
# There are 0 directories and 78 images in data/pizza_steak_sushi/train/pizza.
# There are 0 directories and 72 images in data/pizza_steak_sushi/train/sushi.
# There are 0 directories and 75 images in data/pizza_steak_sushi/train/steak.
# There are 3 directories and 0 images in data/pizza_steak_sushi/test.
# There are 0 directories and 25 images in data/pizza_steak_sushi/test/pizza.
# There are 0 directories and 31 images in data/pizza_steak_sushi/test/sushi.
# There are 0 directories and 19 images in data/pizza_steak_sushi/test/steak.

# %%
train_dir = image_path / 'train'
test_dir = image_path / 'test'

train_dir, test_dir
# Out:
# (PosixPath('data/pizza_steak_sushi/train'),
#  PosixPath('data/pizza_steak_sushi/test'))

# %%
import random
from PIL import Image

random.seed(42)
image_path_list = list(image_path.glob("*/*/*.jpg"))

random_image_path = random.choice(image_path_list)

image_class = random_image_path.parent.stem

img = Image.open(random_image_path)

print(f"Image path: {image_path}")
print(f"Image class: {image_class}")
print(f"Image height: {img.height}")
print(f"Image width: {img.width}")
img
# Out:
# Image path: data/pizza_steak_sushi
# Image class: pizza
# Image height: 384
# Image width: 512
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384>

# %%
import numpy as np
import matplotlib.pyplot as plt

img_as_array = np.asarray(img)

plt.figure(figsize=(10, 7))
plt.imshow(img_as_array)
plt.imshow(img_as_array)
plt.title(f"Image class: {image_class} | Image shape: {img_as_array.shape} -> [height, width, color_channels]")
plt.axis(False)
plt.show()

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
data_transform = transforms.Compose([
    transforms.Resize(size=(64, 64)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor()
])

data_transform(img)
# Out:
# tensor([[[0.5490, 0.5255, 0.4667,  ..., 0.3020, 0.2824, 0.2863],
#          [0.5098, 0.5176, 0.3804,  ..., 0.3373, 0.3020, 0.2863],
#          [0.5333, 0.4392, 0.2706,  ..., 0.3333, 0.3059, 0.2706],
#          ...,
#          [0.2706, 0.2706, 0.2784,  ..., 0.2706, 0.2902, 0.3059],
#          [0.2863, 0.2863, 0.2941,  ..., 0.2549, 0.2824, 0.3098],
#          [0.2784, 0.2784, 0.2824,  ..., 0.2471, 0.2745, 0.2980]],
#
#         [[0.2980, 0.2549, 0.2039,  ..., 0.1333, 0.1216, 0.1216],
#          [0.2902, 0.2863, 0.1373,  ..., 0.1608, 0.1412, 0.1333],
#          [0.3137, 0.2157, 0.0627,  ..., 0.1608, 0.1412, 0.1255],
#          ...,
#          [0.1333, 0.1333, 0.1373,  ..., 0.2314, 0.2471, 0.2588],
#          [0.1333, 0.1333, 0.1373,  ..., 0.2275, 0.2471, 0.2667],
#          [0.1333, 0.1333, 0.1412,  ..., 0.2353, 0.2471, 0.2627]],
#
#         [[0.3451, 0.3373, 0.2667,  ..., 0.0863, 0.0745, 0.0863],
#          [0.3804, 0.4235, 0.2118,  ..., 0.1059, 0.0941, 0.0902],
#          [0.3725, 0.3137, 0.1137,  ..., 0.1020, 0.0941, 0.0824],
#          ...,
#          [0.1333, 0.1412, 0.1216,  ..., 0.1961, 0.2000, 0.2275],
#          [0.1529, 0.1373, 0.1216,  ..., 0.1882, 0.2118, 0.2392],
#          [0.1608, 0.1490, 0.1294,  ..., 0.1804, 0.1961, 0.2196]]])

# %%
def plot_transformed_images(image_paths, transform, n=3, seed=42):
    if seed:
        random.seed(seed)

    random_image_path = random.sample(image_paths, k=n)
    for image_path in random_image_path:
        with Image.open(image_path) as f:
            fig, ax = plt.subplots(nrows=1, ncols=2)
            ax[0].imshow(f)
            ax[0].set_title(f"Original\nSize: {f.size}")
            ax[0].axis(False)

            transformed_image = transform(f).permute(1, 2, 0)
            ax[1].imshow(transformed_image)
            ax[1].set_title(f"Transformed\nShape: {transformed_image.shape}")
            ax[1].axis(False)

            fig.suptitle(f"Class: {image_path.parent.stem}", fontsize=16)


plot_transformed_images(image_paths=image_path_list,
                        transform=data_transform,
                        n=3,
                        seed=None)

# %%
from torchvision import datasets

train_data = datasets.ImageFolder(root=train_dir,
                                  transform=data_transform,
                                  target_transform=None)
test_data = datasets.ImageFolder(root=test_dir,
                                 transform=data_transform,
                                 target_transform=None)

train_data, test_data
# Out:
# (Dataset ImageFolder
#      Number of datapoints: 225
#      Root location: data/pizza_steak_sushi/train
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=None)
#                 RandomHorizontalFlip(p=0.5)
#                 ToTensor()
#             ),
#  Dataset ImageFolder
#      Number of datapoints: 75
#      Root location: data/pizza_steak_sushi/test
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=None)
#                 RandomHorizontalFlip(p=0.5)
#                 ToTensor()
#             ))

# %%
class_names = train_data.classes
class_names
# Out:
# ['pizza', 'steak', 'sushi']

# %%
class_dict = train_data.class_to_idx
class_dict
# Out:
# {'pizza': 0, 'steak': 1, 'sushi': 2}

# %%
len(train_data), len(test_data)
# Out:
# (225, 75)

# %%
from torch.utils.data import DataLoader
import os

BATCH_SIZE = 1
train_dataloader = DataLoader(dataset=train_data,
                              batch_size=BATCH_SIZE,
                              num_workers=os.cpu_count(),
                              shuffle=True)
test_dataloader = DataLoader(dataset=test_data,
                             batch_size=BATCH_SIZE,
                             num_workers=os.cpu_count(),
                             shuffle=False)

train_dataloader, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7f9b3fed76a0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f9b3fec7430>)

# %%
import os
import pathlib
import torch

from PIL import Image
from torch.utils.data import Dataset
from torchvision import transforms
from typing import Tuple, Dict, List

# %%
target_directory = train_dir
class_names_found = sorted([entry.name for entry in list(os.scandir(target_directory))])
class_names_found
# Out:
# ['pizza', 'steak', 'sushi']

# %%
def find_classes(directory: str) -> Tuple[List[str], Dict[str, int]]:
    classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())

    if not classes:
        raise FileNotFoundError(f"Couldn't find any classes in {directory}... Please check file structure.")

    class_to_idx = {class_name: i for i, class_name in enumerate(classes)}

    return classes, class_to_idx

# %%
find_classes(target_directory)
# Out:
# (['pizza', 'steak', 'sushi'], {'pizza': 0, 'steak': 1, 'sushi': 2})

# %%
from torch.utils.data import Dataset


class ImageFolderCustom(Dataset):
    def __init__(self,
                 targ_dir: str,
                 transform=None):
        self.paths = list(pathlib.Path(targ_dir).glob("*/*.jpg"))
        self.transform = transform
        self.classes, self.class_to_idx = find_classes(targ_dir)

    def load_image(self, index: int) -> Image.Image:
        image_path = self.paths[index]
        return Image.open(image_path)

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, index: int) -> Tuple[torch.Tensor, int]:
        img = self.load_image(index)
        class_name = self.paths[index].parent.name
        class_idx = self.class_to_idx[class_name]

        if self.transform:
            return self.transform(img), class_idx

        return img, class_idx

# %%
from torchvision import transforms

train_transforms = transforms.Compose([
    transforms.Resize(size=(64, 64)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor()
])

test_transforms = transforms.Compose([
    transforms.Resize(size=(64, 64)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor()
])

# %%
train_data_custom = ImageFolderCustom(targ_dir=train_dir,
                                      transform=train_transforms)

test_data_custom = ImageFolderCustom(targ_dir=test_dir,
                                     transform=test_transforms)

# %%
train_data_custom, test_data_custom
# Out:
# (<__main__.ImageFolderCustom at 0x7f9b3fe8e220>,
#  <__main__.ImageFolderCustom at 0x7f9b3fe8e310>)

# %%
train_data_custom.classes, len(train_data_custom)
# Out:
# (['pizza', 'steak', 'sushi'], 225)

# %%
def display_random_images(dataset: torch.utils.data.Dataset,
                          classes: List[str] = None,
                          n: int = 10,
                          display_shape: bool = True,
                          seed: int = None):
    if seed:
        random.seed(42)

    if n > 10:
        n = 10
        display_shape = False

    random_samples_idx = random.sample(range(len(dataset)), k=n)

    plt.figure(figsize=(16, 8))

    for i, target_sample in enumerate(random_samples_idx):
        target_image, target_label = dataset[target_sample][0], dataset[target_sample][1]

        target_image_adjust = target_image.permute(1, 2, 0)

        plt.subplot(1, n, i + 1)
        plt.imshow(target_image_adjust)
        plt.axis("off")

        if classes:
            title = f"Class: {classes[target_label]}"
            if display_shape:
                title = title + f"\nShape: {target_image_adjust.shape}"

            plt.title(title)

# %%
display_random_images(train_data,
                      n=5,
                      classes=class_names,
                      seed=None)

# %%
display_random_images(train_data_custom,
                      n=20,
                      classes=class_names,
                      seed=None)

# %%
from torch.utils.data import DataLoader
import os

BATCH_SIZE = 32
NUM_WORKERS = os.cpu_count()
train_dataloader_custom = DataLoader(dataset=train_data_custom,
                                     batch_size=BATCH_SIZE,
                                     num_workers=NUM_WORKERS,
                                     shuffle=True)
test_dataloader_custom = DataLoader(dataset=test_data_custom,
                                    batch_size=BATCH_SIZE,
                                    num_workers=NUM_WORKERS,
                                    shuffle=False)

train_dataloader_custom, test_dataloader_custom
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7f9b41f21e20>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f9b41f21dc0>)

# %%
from torchvision import transforms

train_transforms = transforms.Compose([
    transforms.Resize(size=(64, 64)),
    transforms.TrivialAugmentWide(num_magnitude_bins=31),
    transforms.ToTensor()
])

test_transforms = transforms.Compose([
    transforms.Resize(size=(224, 224)),
    transforms.ToTensor()
])

# %%
image_path_list = list(image_path.glob('*/*/*.jpg'))
image_path_list[:10]
# Out:
# [PosixPath('data/pizza_steak_sushi/train/pizza/2924941.jpg'),
#  PosixPath('data/pizza_steak_sushi/train/pizza/3018077.jpg'),
#  PosixPath('data/pizza_steak_sushi/train/pizza/300869.jpg'),
#  PosixPath('data/pizza_steak_sushi/train/pizza/2228322.jpg'),
#  PosixPath('data/pizza_steak_sushi/train/pizza/393658.jpg'),
#  PosixPath('data/pizza_steak_sushi/train/pizza/702165.jpg'),
#  PosixPath('data/pizza_steak_sushi/train/pizza/1412034.jpg'),
#  PosixPath('data/pizza_steak_sushi/train/pizza/2811032.jpg'),
#  PosixPath('data/pizza_steak_sushi/train/pizza/2569760.jpg'),
#  PosixPath('data/pizza_steak_sushi/train/pizza/3860002.jpg')]

# %%
plot_transformed_images(image_paths=image_path_list,
                        transform=train_transforms,
                        n=3,
                        seed=None)

# %% [markdown]
# ## Replicate TinyVGG

# %%
simple_transform = transforms.Compose([
    transforms.Resize(size=(64, 64)),
    transforms.ToTensor()
])

# %%
from torchvision import datasets

train_data_simple = datasets.ImageFolder(root=train_dir,
                                         transform=simple_transform)
test_data_simple = datasets.ImageFolder(root=test_dir,
                                        transform=simple_transform)

# %%
import os
from torch.utils.data import DataLoader

BATCH_SIZE = 32
NUM_WORKERS = os.cpu_count()

train_dataloader_simple = DataLoader(dataset=train_data_simple,
                                     batch_size=BATCH_SIZE,
                                     shuffle=True,
                                     num_workers=NUM_WORKERS)
test_dataloader_simple = DataLoader(dataset=test_data_simple,
                                    batch_size=BATCH_SIZE,
                                    shuffle=False,
                                    num_workers=NUM_WORKERS)

# %%
class TinyVGG(nn.Module):
    def __init__(self, input_shape: int,
                 hidden_units: int,
                 output_shape: int) -> None:
        super().__init__()
        self.conv_block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2)
        )
        self.conv_block_2 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=hidden_units * 16 * 16,
                      out_features=output_shape)
        )

    def forward(self, x):
        return self.classifier(self.conv_block_2(self.conv_block_1(x)))

# %%
torch.manual_seed(42)
model = TinyVGG(input_shape=3,
                hidden_units=10,
                output_shape=len(class_names)).to(device)

model
# Out:
# TinyVGG(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=2560, out_features=3, bias=True)
#   )
# )

# %%
from torchinfo import summary

summary(model, input_size=[1, 3, 64, 64])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TinyVGG                                  [1, 3]                    --
# ├─Sequential: 1-1                        [1, 10, 32, 32]           --
# │    └─Conv2d: 2-1                       [1, 10, 64, 64]           280
# │    └─ReLU: 2-2                         [1, 10, 64, 64]           --
# │    └─Conv2d: 2-3                       [1, 10, 64, 64]           910
# │    └─ReLU: 2-4                         [1, 10, 64, 64]           --
# │    └─MaxPool2d: 2-5                    [1, 10, 32, 32]           --
# ├─Sequential: 1-2                        [1, 10, 16, 16]           --
# │    └─Conv2d: 2-6                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-7                         [1, 10, 32, 32]           --
# │    └─Conv2d: 2-8                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-9                         [1, 10, 32, 32]           --
# │    └─MaxPool2d: 2-10                   [1, 10, 16, 16]           --
# ├─Sequential: 1-3                        [1, 3]                    --
# │    └─Flatten: 2-11                     [1, 2560]                 --
# │    └─Linear: 2-12                      [1, 3]                    7,683
# ==========================================================================================
# Total params: 10,693
# Trainable params: 10,693
# Non-trainable params: 0
# Total mult-adds (M): 6.75
# ==========================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.91
# ==========================================================================================

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               device=device):
    model.train()

    train_loss, train_acc = 0, 0

    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        y_pred = model(X)

        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item() / len(y_pred)

    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)

    return train_loss, train_acc

# %%
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device=device):
    model.eval()

    test_loss, test_acc = 0, 0

    with torch.inference_mode():
        for batch, (X, y) in enumerate(dataloader):
            X, y = X.to(device), y.to(device)

            test_pred_logits = model(X)

            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            test_pred_labels = torch.argmax(torch.softmax(test_pred_logits, dim=1), dim=1)
            test_acc += (test_pred_labels == y).sum().item() / len(test_pred_logits)

        test_loss = test_loss / len(dataloader)
        test_acc = test_acc / len(dataloader)

    return test_loss, test_acc

# %%
from tqdm.auto import tqdm


def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5,
          device=device):
    results = {"train_loss": [],
               "train_acc": [],
               "test_loss": [],
               "test_acc": []}

    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer,
                                           device=device)
        test_loss, test_acc = test_step(model=model,
                                        dataloader=test_dataloader,
                                        loss_fn=loss_fn,
                                        device=device)

        print(
            f"Epoch: {epoch} | Train loss: {train_loss:.4f} | Train acc : {train_acc:.4f} | Test loss: {test_loss:.4f} | Test acc: {test_acc:.4f}")

        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

    return results

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

NUM_EPOCHS = 150

model = TinyVGG(input_shape=3,
                hidden_units=15,
                output_shape=len(class_names)).to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(),
                             lr=0.0001)

from timeit import default_timer as timer

start_time = timer()

model_results = train(model=model,
                      train_dataloader=train_dataloader_simple,
                      test_dataloader=test_dataloader_simple,
                      optimizer=optimizer,
                      loss_fn=loss_fn,
                      epochs=NUM_EPOCHS,
                      device=device)

end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds.")
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch: 0 | Train loss: 1.0937 | Train acc : 0.4258 | Test loss: 1.1047 | Test acc: 0.2604
# Epoch: 1 | Train loss: 1.1018 | Train acc : 0.3047 | Test loss: 1.1118 | Test acc: 0.2604
# Epoch: 2 | Train loss: 1.1067 | Train acc : 0.3047 | Test loss: 1.1196 | Test acc: 0.2604
# Epoch: 3 | Train loss: 1.0910 | Train acc : 0.4258 | Test loss: 1.1116 | Test acc: 0.2604
# Epoch: 4 | Train loss: 1.1041 | Train acc : 0.3047 | Test loss: 1.1101 | Test acc: 0.2604
# Epoch: 5 | Train loss: 1.0989 | Train acc : 0.3047 | Test loss: 1.1001 | Test acc: 0.2604
# Epoch: 6 | Train loss: 1.1030 | Train acc : 0.3047 | Test loss: 1.0901 | Test acc: 0.3722
# Epoch: 7 | Train loss: 1.0969 | Train acc : 0.3281 | Test loss: 1.0925 | Test acc: 0.5133
# Epoch: 8 | Train loss: 1.0917 | Train acc : 0.4492 | Test loss: 1.0995 | Test acc: 0.2604
# Epoch: 9 | Train loss: 1.0987 | Train acc : 0.3047 | Test loss: 1.1049 | Test acc: 0.2604
# Epoch: 10 | Train loss: 1.0859 | Train acc : 0.4258 | Test loss: 1.1000 | Test acc: 0.2604
# Epoch: 11 | Train loss: 1.0992 | Train acc : 0.3047 | Test loss: 1.1026 | Test acc: 0.2604
# Epoch: 12 | Train loss: 1.0849 | Train acc : 0.4258 | Test loss: 1.1078 | Test acc: 0.2604
# Epoch: 13 | Train loss: 1.0813 | Train acc : 0.4258 | Test loss: 1.1159 | Test acc: 0.2604
# Epoch: 14 | Train loss: 1.0732 | Train acc : 0.4258 | Test loss: 1.1215 | Test acc: 0.2604
# Epoch: 15 | Train loss: 1.0917 | Train acc : 0.3047 | Test loss: 1.1268 | Test acc: 0.2604
# Epoch: 16 | Train loss: 1.0810 | Train acc : 0.3047 | Test loss: 1.1305 | Test acc: 0.2917
# Epoch: 17 | Train loss: 1.0710 | Train acc : 0.5195 | Test loss: 1.1384 | Test acc: 0.2396
# Epoch: 18 | Train loss: 1.0841 | Train acc : 0.3438 | Test loss: 1.1426 | Test acc: 0.2292
# Epoch: 19 | Train loss: 1.0946 | Train acc : 0.4141 | Test loss: 1.1339 | Test acc: 0.3021
# Epoch: 20 | Train loss: 1.0674 | Train acc : 0.6016 | Test loss: 1.1160 | Test acc: 0.3125
# Epoch: 21 | Train loss: 1.0595 | Train acc : 0.5234 | Test loss: 1.1127 | Test acc: 0.2917
# Epoch: 22 | Train loss: 1.0510 | Train acc : 0.5430 | Test loss: 1.1105 | Test acc: 0.3333
# Epoch: 23 | Train loss: 1.0580 | Train acc : 0.4727 | Test loss: 1.1127 | Test acc: 0.2812
# Epoch: 24 | Train loss: 1.0634 | Train acc : 0.4766 | Test loss: 1.1089 | Test acc: 0.3229
# Epoch: 25 | Train loss: 1.0222 | Train acc : 0.6211 | Test loss: 1.0861 | Test acc: 0.3021
# Epoch: 26 | Train loss: 1.0129 | Train acc : 0.5820 | Test loss: 1.0889 | Test acc: 0.3021
# Epoch: 27 | Train loss: 1.0453 | Train acc : 0.3867 | Test loss: 1.0901 | Test acc: 0.2917
# Epoch: 28 | Train loss: 1.0465 | Train acc : 0.4453 | Test loss: 1.0629 | Test acc: 0.3220
# Epoch: 29 | Train loss: 1.0050 | Train acc : 0.4961 | Test loss: 1.0593 | Test acc: 0.3314
# Epoch: 30 | Train loss: 0.9923 | Train acc : 0.5234 | Test loss: 1.0683 | Test acc: 0.3011
# Epoch: 31 | Train loss: 0.9550 | Train acc : 0.6641 | Test loss: 1.0521 | Test acc: 0.4034
# Epoch: 32 | Train loss: 0.9305 | Train acc : 0.6172 | Test loss: 1.0609 | Test acc: 0.3116
# Epoch: 33 | Train loss: 1.0101 | Train acc : 0.5039 | Test loss: 1.0693 | Test acc: 0.3116
# Epoch: 34 | Train loss: 0.9381 | Train acc : 0.6602 | Test loss: 1.1005 | Test acc: 0.2604
# Epoch: 35 | Train loss: 0.9686 | Train acc : 0.5312 | Test loss: 1.0546 | Test acc: 0.3722
# Epoch: 36 | Train loss: 0.9330 | Train acc : 0.5625 | Test loss: 1.0129 | Test acc: 0.3930
# Epoch: 37 | Train loss: 0.9222 | Train acc : 0.5547 | Test loss: 0.9897 | Test acc: 0.4432
# Epoch: 38 | Train loss: 0.8888 | Train acc : 0.6719 | Test loss: 1.0087 | Test acc: 0.4129
# Epoch: 39 | Train loss: 0.8929 | Train acc : 0.6719 | Test loss: 1.0006 | Test acc: 0.3930
# Epoch: 40 | Train loss: 0.9699 | Train acc : 0.5312 | Test loss: 1.0320 | Test acc: 0.3627
# Epoch: 41 | Train loss: 0.9033 | Train acc : 0.5586 | Test loss: 1.0429 | Test acc: 0.4034
# Epoch: 42 | Train loss: 0.8791 | Train acc : 0.5742 | Test loss: 1.0260 | Test acc: 0.4129
# Epoch: 43 | Train loss: 0.9116 | Train acc : 0.5625 | Test loss: 0.9934 | Test acc: 0.3930
# Epoch: 44 | Train loss: 0.8670 | Train acc : 0.5625 | Test loss: 1.0047 | Test acc: 0.4441
# Epoch: 45 | Train loss: 0.8726 | Train acc : 0.5898 | Test loss: 0.9868 | Test acc: 0.4242
# Epoch: 46 | Train loss: 0.8796 | Train acc : 0.5703 | Test loss: 0.9655 | Test acc: 0.4839
# Epoch: 47 | Train loss: 0.8244 | Train acc : 0.6836 | Test loss: 0.9525 | Test acc: 0.5038
# Epoch: 48 | Train loss: 0.8668 | Train acc : 0.5586 | Test loss: 0.9525 | Test acc: 0.5142
# Epoch: 49 | Train loss: 1.0340 | Train acc : 0.5586 | Test loss: 0.9845 | Test acc: 0.5047
# Epoch: 50 | Train loss: 0.8028 | Train acc : 0.7227 | Test loss: 1.0158 | Test acc: 0.4545
# Epoch: 51 | Train loss: 0.7702 | Train acc : 0.6836 | Test loss: 1.0432 | Test acc: 0.4034
# Epoch: 52 | Train loss: 0.8792 | Train acc : 0.6055 | Test loss: 1.0209 | Test acc: 0.3523
# Epoch: 53 | Train loss: 0.7436 | Train acc : 0.7227 | Test loss: 0.9893 | Test acc: 0.4233
# Epoch: 54 | Train loss: 0.7961 | Train acc : 0.6836 | Test loss: 0.9784 | Test acc: 0.4640
# Epoch: 55 | Train loss: 0.8636 | Train acc : 0.5977 | Test loss: 0.9568 | Test acc: 0.5256
# Epoch: 56 | Train loss: 0.7810 | Train acc : 0.7148 | Test loss: 0.9965 | Test acc: 0.4545
# Epoch: 57 | Train loss: 0.7607 | Train acc : 0.7305 | Test loss: 1.0111 | Test acc: 0.4347
# Epoch: 58 | Train loss: 0.7201 | Train acc : 0.6797 | Test loss: 1.0648 | Test acc: 0.3722
# Epoch: 59 | Train loss: 0.7305 | Train acc : 0.6758 | Test loss: 1.0218 | Test acc: 0.4138
# Epoch: 60 | Train loss: 0.6698 | Train acc : 0.7227 | Test loss: 1.0152 | Test acc: 0.4347
# Epoch: 61 | Train loss: 0.7638 | Train acc : 0.6211 | Test loss: 1.0000 | Test acc: 0.4441
# Epoch: 62 | Train loss: 0.7606 | Train acc : 0.5703 | Test loss: 0.9931 | Test acc: 0.4233
# Epoch: 63 | Train loss: 0.6835 | Train acc : 0.7461 | Test loss: 0.9453 | Test acc: 0.5360
# Epoch: 64 | Train loss: 0.6870 | Train acc : 0.7656 | Test loss: 0.9587 | Test acc: 0.5057
# Epoch: 65 | Train loss: 0.6791 | Train acc : 0.7344 | Test loss: 0.9465 | Test acc: 0.5464
# Epoch: 66 | Train loss: 0.7331 | Train acc : 0.7461 | Test loss: 0.9451 | Test acc: 0.5464
# Epoch: 67 | Train loss: 0.7326 | Train acc : 0.5898 | Test loss: 0.9965 | Test acc: 0.4545
# Epoch: 68 | Train loss: 0.6519 | Train acc : 0.7383 | Test loss: 1.0079 | Test acc: 0.4650
# Epoch: 69 | Train loss: 0.7229 | Train acc : 0.7461 | Test loss: 1.0063 | Test acc: 0.4659
# Epoch: 70 | Train loss: 0.6505 | Train acc : 0.7539 | Test loss: 0.9888 | Test acc: 0.4650
# Epoch: 71 | Train loss: 0.8361 | Train acc : 0.6094 | Test loss: 0.9596 | Test acc: 0.5464
# Epoch: 72 | Train loss: 0.7072 | Train acc : 0.7500 | Test loss: 0.9902 | Test acc: 0.4754
# Epoch: 73 | Train loss: 0.6497 | Train acc : 0.7148 | Test loss: 1.0618 | Test acc: 0.3930
# Epoch: 74 | Train loss: 0.6430 | Train acc : 0.7148 | Test loss: 1.0093 | Test acc: 0.4962
# Epoch: 75 | Train loss: 0.6811 | Train acc : 0.7461 | Test loss: 0.9828 | Test acc: 0.5057
# Epoch: 76 | Train loss: 0.6114 | Train acc : 0.7695 | Test loss: 0.9475 | Test acc: 0.5464
# Epoch: 77 | Train loss: 0.7034 | Train acc : 0.6133 | Test loss: 0.9509 | Test acc: 0.5464
# Epoch: 78 | Train loss: 0.6528 | Train acc : 0.7852 | Test loss: 0.9936 | Test acc: 0.4650
# Epoch: 79 | Train loss: 0.6403 | Train acc : 0.7578 | Test loss: 1.0075 | Test acc: 0.4754
# Epoch: 80 | Train loss: 0.6022 | Train acc : 0.7422 | Test loss: 1.0087 | Test acc: 0.4545
# Epoch: 81 | Train loss: 0.6730 | Train acc : 0.6211 | Test loss: 0.9579 | Test acc: 0.5265
# Epoch: 82 | Train loss: 0.6852 | Train acc : 0.6367 | Test loss: 0.9035 | Test acc: 0.5663
# Epoch: 83 | Train loss: 0.6970 | Train acc : 0.7695 | Test loss: 0.8884 | Test acc: 0.6061
# Epoch: 84 | Train loss: 0.7345 | Train acc : 0.6445 | Test loss: 0.9144 | Test acc: 0.5559
# Epoch: 85 | Train loss: 0.6363 | Train acc : 0.7109 | Test loss: 1.0789 | Test acc: 0.4129
# Epoch: 86 | Train loss: 0.6023 | Train acc : 0.7188 | Test loss: 0.9864 | Test acc: 0.4754
# Epoch: 87 | Train loss: 0.6404 | Train acc : 0.7695 | Test loss: 0.9677 | Test acc: 0.4848
# Epoch: 88 | Train loss: 0.5780 | Train acc : 0.7812 | Test loss: 0.9347 | Test acc: 0.5568
# Epoch: 89 | Train loss: 0.7205 | Train acc : 0.6484 | Test loss: 0.9259 | Test acc: 0.5871
# Epoch: 90 | Train loss: 0.6837 | Train acc : 0.6484 | Test loss: 0.9143 | Test acc: 0.5663
# Epoch: 91 | Train loss: 0.5840 | Train acc : 0.7656 | Test loss: 0.9209 | Test acc: 0.5777
# Epoch: 92 | Train loss: 0.6140 | Train acc : 0.7891 | Test loss: 0.9131 | Test acc: 0.5767
# Epoch: 93 | Train loss: 0.6326 | Train acc : 0.7852 | Test loss: 0.8938 | Test acc: 0.6278
# Epoch: 94 | Train loss: 0.5633 | Train acc : 0.7930 | Test loss: 0.8893 | Test acc: 0.6477
# Epoch: 95 | Train loss: 0.5904 | Train acc : 0.7891 | Test loss: 0.9401 | Test acc: 0.5672
# Epoch: 96 | Train loss: 0.5850 | Train acc : 0.7695 | Test loss: 0.9845 | Test acc: 0.5275
# Epoch: 97 | Train loss: 0.5433 | Train acc : 0.7773 | Test loss: 0.9675 | Test acc: 0.5275
# Epoch: 98 | Train loss: 0.5848 | Train acc : 0.7852 | Test loss: 0.9582 | Test acc: 0.5170
# Epoch: 99 | Train loss: 0.5600 | Train acc : 0.7852 | Test loss: 0.9855 | Test acc: 0.5066
# Epoch: 100 | Train loss: 0.5588 | Train acc : 0.7852 | Test loss: 0.9929 | Test acc: 0.5275
# Epoch: 101 | Train loss: 0.5369 | Train acc : 0.7812 | Test loss: 0.9598 | Test acc: 0.5170
# Epoch: 102 | Train loss: 0.6673 | Train acc : 0.6641 | Test loss: 0.9476 | Test acc: 0.5568
# Epoch: 103 | Train loss: 0.5507 | Train acc : 0.7812 | Test loss: 0.9928 | Test acc: 0.5256
# Epoch: 104 | Train loss: 0.5331 | Train acc : 0.7969 | Test loss: 0.9970 | Test acc: 0.5170
# Epoch: 105 | Train loss: 0.6115 | Train acc : 0.7930 | Test loss: 0.9364 | Test acc: 0.5473
# Epoch: 106 | Train loss: 0.5320 | Train acc : 0.8008 | Test loss: 0.8883 | Test acc: 0.6373
# Epoch: 107 | Train loss: 0.5529 | Train acc : 0.8047 | Test loss: 0.9392 | Test acc: 0.5672
# Epoch: 108 | Train loss: 0.5189 | Train acc : 0.7891 | Test loss: 0.9724 | Test acc: 0.5881
# Epoch: 109 | Train loss: 0.5661 | Train acc : 0.7930 | Test loss: 0.9758 | Test acc: 0.5066
# Epoch: 110 | Train loss: 0.5354 | Train acc : 0.7969 | Test loss: 0.9944 | Test acc: 0.5170
# Epoch: 111 | Train loss: 0.5262 | Train acc : 0.7969 | Test loss: 0.9770 | Test acc: 0.5066
# Epoch: 112 | Train loss: 0.5159 | Train acc : 0.8047 | Test loss: 0.9679 | Test acc: 0.5170
# Epoch: 113 | Train loss: 0.5866 | Train acc : 0.6719 | Test loss: 0.9349 | Test acc: 0.5369
# Epoch: 114 | Train loss: 0.5653 | Train acc : 0.7852 | Test loss: 0.9038 | Test acc: 0.6278
# Epoch: 115 | Train loss: 0.5188 | Train acc : 0.8047 | Test loss: 1.0064 | Test acc: 0.5265
# Epoch: 116 | Train loss: 0.5125 | Train acc : 0.7930 | Test loss: 0.9576 | Test acc: 0.5369
# Epoch: 117 | Train loss: 0.4902 | Train acc : 0.8125 | Test loss: 0.9657 | Test acc: 0.5066
# Epoch: 118 | Train loss: 0.5455 | Train acc : 0.8047 | Test loss: 0.9735 | Test acc: 0.4962
# Epoch: 119 | Train loss: 0.7263 | Train acc : 0.6797 | Test loss: 0.9226 | Test acc: 0.6174
# Epoch: 120 | Train loss: 0.5224 | Train acc : 0.8125 | Test loss: 1.0054 | Test acc: 0.5663
# Epoch: 121 | Train loss: 0.5033 | Train acc : 0.8125 | Test loss: 1.0257 | Test acc: 0.4659
# Epoch: 122 | Train loss: 0.5284 | Train acc : 0.7812 | Test loss: 1.0180 | Test acc: 0.4972
# Epoch: 123 | Train loss: 0.4828 | Train acc : 0.8086 | Test loss: 1.0062 | Test acc: 0.5066
# Epoch: 124 | Train loss: 0.6116 | Train acc : 0.6953 | Test loss: 0.9710 | Test acc: 0.5871
# Epoch: 125 | Train loss: 0.5135 | Train acc : 0.8320 | Test loss: 1.0128 | Test acc: 0.4754
# Epoch: 126 | Train loss: 0.6209 | Train acc : 0.7031 | Test loss: 1.0354 | Test acc: 0.4659
# Epoch: 127 | Train loss: 0.5059 | Train acc : 0.8164 | Test loss: 1.0612 | Test acc: 0.4962
# Epoch: 128 | Train loss: 0.5601 | Train acc : 0.8086 | Test loss: 0.9993 | Test acc: 0.4763
# Epoch: 129 | Train loss: 0.5464 | Train acc : 0.8281 | Test loss: 0.9334 | Test acc: 0.6278
# Epoch: 130 | Train loss: 0.5008 | Train acc : 0.7891 | Test loss: 1.0436 | Test acc: 0.4754
# Epoch: 131 | Train loss: 0.4782 | Train acc : 0.8086 | Test loss: 0.9890 | Test acc: 0.5672
# Epoch: 132 | Train loss: 0.5160 | Train acc : 0.8320 | Test loss: 0.9893 | Test acc: 0.4867
# Epoch: 133 | Train loss: 0.4958 | Train acc : 0.8047 | Test loss: 1.0404 | Test acc: 0.4858
# Epoch: 134 | Train loss: 0.4595 | Train acc : 0.8047 | Test loss: 0.9609 | Test acc: 0.5672
# Epoch: 135 | Train loss: 0.4713 | Train acc : 0.8398 | Test loss: 0.9702 | Test acc: 0.5777
# Epoch: 136 | Train loss: 0.5196 | Train acc : 0.8320 | Test loss: 0.9901 | Test acc: 0.5170
# Epoch: 137 | Train loss: 0.4867 | Train acc : 0.8242 | Test loss: 0.9487 | Test acc: 0.6383
# Epoch: 138 | Train loss: 0.4615 | Train acc : 0.8281 | Test loss: 1.0206 | Test acc: 0.5265
# Epoch: 139 | Train loss: 0.5070 | Train acc : 0.8164 | Test loss: 0.9643 | Test acc: 0.5975
# Epoch: 140 | Train loss: 0.4592 | Train acc : 0.8320 | Test loss: 0.9771 | Test acc: 0.5767
# Epoch: 141 | Train loss: 0.4880 | Train acc : 0.8164 | Test loss: 1.0293 | Test acc: 0.4754
# Epoch: 142 | Train loss: 0.4471 | Train acc : 0.8164 | Test loss: 1.0693 | Test acc: 0.4867
# Epoch: 143 | Train loss: 0.4373 | Train acc : 0.8398 | Test loss: 1.0201 | Test acc: 0.5170
# Epoch: 144 | Train loss: 0.5254 | Train acc : 0.7109 | Test loss: 0.9968 | Test acc: 0.5568
# Epoch: 145 | Train loss: 0.4964 | Train acc : 0.8281 | Test loss: 1.0718 | Test acc: 0.5265
# Epoch: 146 | Train loss: 0.4574 | Train acc : 0.8320 | Test loss: 1.0473 | Test acc: 0.4962
# Epoch: 147 | Train loss: 0.6936 | Train acc : 0.7227 | Test loss: 1.0612 | Test acc: 0.5265
# Epoch: 148 | Train loss: 0.6614 | Train acc : 0.6719 | Test loss: 1.0223 | Test acc: 0.5568
# Epoch: 149 | Train loss: 0.4738 | Train acc : 0.8203 | Test loss: 1.0248 | Test acc: 0.5663
# Total training time: 108.265 seconds.

# %%
def plot_loss_curves(results: Dict[str, List[float]]):
    loss = results["train_loss"]
    test_loss = results["test_loss"]

    acc = results["train_acc"]
    test_acc = results["test_acc"]

    epochs = range(len(results["train_loss"]))

    plt.figure(figsize=(15, 7))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label="train_loss")
    plt.plot(epochs, test_loss, label="test_loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, acc, label="train_acc")
    plt.plot(epochs, test_acc, label="test_acc")
    plt.title("Accuracy")
    plt.xlabel("Epochs")
    plt.legend()

    plt.show()

# %%
plot_loss_curves(results=model_results)
